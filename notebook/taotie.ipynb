# %%
import pandas as pd # Option/ALT+Enter

# %%
df = pd.read_parquet('../assets/sample.parquet')

# %%
df
# Out:
#                               email name   gender  \
# 0        garth.hd167xho@example.net  严鸿灿   female
# 1       marlen.a6aqn616@example.net  汪歆翠   female
# 2         aida.gf3qhygg@example.com  钟晋运     male
# 3    magdalena.if93w4mk@example.org  罗醉珊     male
# 4       malika.k44j8fuk@example.org  陶秋荷   female
# ..                              ...  ...      ...
# 995    margret.xxq4hw5s@example.org  林海亦     male
# 996        leo.t9axqasx@example.com  黄雪娅  unknown
# 997      jesse.2rz1125j@example.org  谢睿轩     male
# 998     hertha.sq2zh2fj@example.net  李弘邦   female
# 999     vickie.zccjqx9y@example.org  许采菡   female
#
#                           created_at                  last_visited_at  \
# 0   2022-02-27 22:41:16.419562+00:00 2024-06-04 02:14:16.419563+00:00
# 1   2021-05-20 04:54:16.414246+00:00 2024-06-11 17:07:16.414246+00:00
# 2   2022-10-10 08:13:16.413362+00:00 2024-06-19 11:53:16.413363+00:00
# 3   2019-09-28 18:31:16.413734+00:00 2024-06-26 00:32:16.413734+00:00
# ...

# %%
df.describe()
# Out:
#                              email  name  gender  \
# count                         1000  1000    1000
# unique                        1000   984       3
# top     garth.hd167xho@example.net   苏厉轩  female
# freq                             1     2     351
# mean                           NaN   NaN     NaN
# min                            NaN   NaN     NaN
# 25%                            NaN   NaN     NaN
# 50%                            NaN   NaN     NaN
# 75%                            NaN   NaN     NaN
# max                            NaN   NaN     NaN
#
#                               created_at                   last_visited_at  \
# count                               1000                              1000
# unique                               NaN                               NaN
# top                                  NaN                               NaN
# freq                                 NaN                               NaN
# ...
